# %% [markdown]
# # 라이브러리

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
oneway_anova_result = stats.f_oneway(type1, type2, type3, type4)

# %%
# 등분산 검정 Levene
levene = stats.levene(type1, type2, type3, typ4)

# %%
# 등분산 검정 Levene
levene = stats.levene(type1, type2, type3, typ4, center="mean")

# %%
# 사후검정
from statsmodels.stats.multicomp import pairwise_tukeyhsd

posthoc = pairwise_tukeyhsd(df_f_oneway['defRate'], df_f_oneway['type'], alpha=0.05)
