# %% [markdown]
# # 라이브러리

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# 등분산 검정 레빈(Levene) -> 정규성을 만족하지 않을 경우
stats.levene(arr_yes, arr_no)

# 등분산 검정 바틀렛(Bartlett) -> 정규성을 만족할 경우
stats.bartlett(arr_yes, arr_no)

stats.ttest_ind(arr_no, arr_yes, equal_var=True)
